# %% [markdown]
# # Matplotlib基本練習

# %% [markdown]
# # 1.繪製簡單的折線圖

# %%
# 請在"填空"處，輸入所需要的指令或參數

import pandas as pd
import matplotlib.pyplot as plt

products = {"分類": ["居家","居家","娛樂","娛樂","科技","科技"],
       "商店": ["家樂福A","大潤發A","家樂福B","全聯超A","大潤發B","家樂福C"],
       "價格": [11.42,23.50,19.99,15.95,55.75,111.55]}

df = pd.DataFrame(products, columns = ["分類", "商店", "價格"])
df["價格"].plot(kind="line") # 繪製折線圖
plt.grid([True]) # 顯示圖表的格線

# %%
# Colab 進行matplotlib繪圖時顯示繁體中文
# 下載台北思源黑體並命名taipei_sans_tc_beta.ttf，移至指定路徑
# !wget -O TaipeiSansTCBeta-Regular.ttf https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_&export=download

import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.font_manager import fontManager

fontManager.addfont('TaipeiSansTCBeta-Regular.ttf')
mpl.rc('font', family='Taipei Sans TC Beta')
# Out:
# --2024-04-01 17:48:00--  https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.google.com (drive.google.com)... 142.251.2.138, 142.251.2.139, 142.251.2.113, ...
# Connecting to drive.google.com (drive.google.com)|142.251.2.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_ [following]
# --2024-04-01 17:48:00--  https://drive.usercontent.google.com/download?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.251.2.132, 2607:f8b0:4023:c0d::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.251.2.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20659344 (20M) [application/octet-stream]
# Saving to: ‘TaipeiSansTCBeta-Regular.ttf’
#
# TaipeiSansTCBeta-Re 100%[===================>]  19.70M  70.9MB/s    in 0.3s
#
# 2024-04-01 17:48:05 (70.9 MB/s) - ‘TaipeiSansTCBeta-Regular.ttf’ saved [20659344/20659344]

# %% [markdown]
# # 2.顯示x軸和y軸的說明標籤

# %%
# 請在"填空"處，輸入所需要的指令或參數
# Line 3-12行請複製上一題3-12行的解答
import pandas as pd
import matplotlib.pyplot as plt

products = {"分類": ["居家","居家","娛樂","娛樂","科技","科技"],
       "商店": ["家樂福A","大潤發A","家樂福B","全聯超A","大潤發B","家樂福C"],
       "價格": [11.42,23.50,19.99,15.95,55.75,111.55]}
df = pd.DataFrame(products, columns = ["分類", "商店", "價格"])
df["價格"].plot(kind="line") # 繪製折線圖
plt.grid([True]) # 顯示圖表的格線
# 延伸上一題相同內容

plt.xticks([0, 1, 2, 3, 4, 5], df["商店"])
plt.xlabel("商店名稱")
plt.ylabel("價格")
# Out:
# Text(0, 0.5, '價格')

# %% [markdown]
# # 3.請繪製水平長條圖

# %%
# 請在"填空"處，輸入所需要的指令或參數
# Line 3-18行請複製上一題3-18行的解答

import pandas as pd
import matplotlib.pyplot as plt

products = {"分類": ["居家","居家","娛樂","娛樂","科技","科技"],
       "商店": ["家樂福A","大潤發A","家樂福B","全聯超A","大潤發B","家樂福C"],
       "價格": [11.42,23.50,19.99,15.95,55.75,111.55]}
df = pd.DataFrame(products, columns = ["分類", "商店", "價格"])
df["價格"].plot(kind="barh") # 繪製折線圖
# 延伸上一題相同內容

plt.xlabel("價格")
plt.ylabel("商品名稱")
plt.grid(True) # 顯示圖表的格線
# 延伸上一題相同內容
# 水平長條圖 (X軸是價格金額，Y軸是商店名稱)
plt.yticks([0, 1, 2, 3, 4, 5], ["家樂福A","大潤發A","家樂福B","全聯超A","大潤發B","家樂福C"])
# Out:
# ([<matplotlib.axis.YTick at 0x7f70f44a8be0>,
#   <matplotlib.axis.YTick at 0x7f70f44a8580>,
#   <matplotlib.axis.YTick at 0x7f70f44808b0>,
#   <matplotlib.axis.YTick at 0x7f70f44d0df0>,
#   <matplotlib.axis.YTick at 0x7f70f44d18a0>,
#   <matplotlib.axis.YTick at 0x7f70f44d2350>],
#  [Text(0, 0, '家樂福A'),
#   Text(0, 1, '大潤發A'),
#   Text(0, 2, '家樂福B'),
#   Text(0, 3, '全聯超A'),
#   Text(0, 4, '大潤發B'),
#   Text(0, 5, '家樂福C')])

# %% [markdown]
# # 4.請繪製派圖

# %%
import pandas as pd
import matplotlib.pyplot as plt

products = {"分類": ["居家","居家","娛樂","娛樂","科技","科技"],
       "商店": ["家樂福A","大潤發A","家樂福B","全聯超A","大潤發B","家樂福C"],
       "價格": [11.42,23.50,19.99,15.95,55.75,111.55]}

df = pd.DataFrame(products, columns = ["分類", "商店", "價格"])
plt.grid(True) # 顯示圖表的格線

# 派圖(groupby 是依據"分類"的數據，標題是商店名稱)
df_grouped = df.groupby("分類")
type = df_grouped["分類"].count()
type.plot(kind="pie", title="商店分類")
plt.ylabel("")
# Out:
# Text(0, 0.5, '')
